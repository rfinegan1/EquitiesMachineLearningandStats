# %%
import pandas as pd
import pandas_datareader.data as web
import numpy as np
import math
import datetime as dt
import matplotlib as mpl
import matplotlib.pyplot as plt
import statistics as stats
import scipy
from scipy.stats.stats import pearsonr
from matplotlib import style
import warnings
import seaborn as sns
import requests
import bs4 as bs
import os
import csv
from openpyxl.workbook import Workbook as wb
from openpyxl import load_workbook
from openpyxl.styles import Font
from openpyxl.utils.dataframe import dataframe_to_rows
from pylab import rcParams
from sklearn import linear_model
import statsmodels.api as sm
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
warnings.filterwarnings('ignore')

# %%
'''USE FF_Research_Data, col (RM-RF) + col (RF) = RM(t) to generate beta
Annual Excess Return: rp(t) – RF(t) , where RF(t) comes from FF.
R_j(t) = RF(t) + beta_j*( RM-RF  ), rewrite differently
R_j(t) – RF(t) =  ( RM(t)-RF(t)  )*beta_j'''
# Out:
# 'USE FF_Research_Data, col (RM-RF) + col (RF) = RM(t) to generate beta\nAnnual Excess Return: rp(t) – RF(t) , where RF(t) comes from FF.\nR_j(t) = RF(t) + beta_j*( RM-RF  ), rewrite differently\nR_j(t) – RF(t) =  ( RM(t)-RF(t)  )*beta_j'

# %%
data = pd.read_excel('stock_returns_data.xlsx')

# %%
df = data[['Names Date','Ticker Symbol','Returns']]

# %%
df = df[pd.to_numeric(df['Returns'], errors='coerce').notnull()]

# %%
df['Date'] = df['Names Date'].apply(lambda x: pd.to_datetime(str(x), format='%Y%m%d'))
df
# Out:
#          Names Date Ticker Symbol   Returns       Date
# 0          20070131          EWST  0.023279 2007-01-31
# 1          20070228          EWST  0.261621 2007-02-28
# 2          20070330          EWST  0.019732 2007-03-30
# 3          20070430          EWST  0.002764 2007-04-30
# 4          20070531          EWST  0.043418 2007-05-31
# ...             ...           ...       ...        ...
# 1048568    20191129            VT  0.025614 2019-11-29
# 1048569    20191231            VT  0.034494 2019-12-31
# 1048572    20080731           SZR  0.076445 2008-07-31
# 1048573    20080829           SZR -0.040735 2008-08-29
# 1048574    20080930           SZR -0.063134 2008-09-30
#
# [1021412 rows x 4 columns]

# %%
df['Returns']=df['Returns']*100
df1 = df[['Date','Ticker Symbol','Returns']]
df1['Date'] = df1['Date'].map(lambda x: 100*x.year + x.month)
df1['Date'] = df1['Date'].apply(lambda x: pd.to_datetime(str(x), format='%Y%m'))
df1
# Out:
#               Date Ticker Symbol  Returns
# 0       2007-01-01          EWST   2.3279
# 1       2007-02-01          EWST  26.1621
# 2       2007-03-01          EWST   1.9732
# 3       2007-04-01          EWST   0.2764
# 4       2007-05-01          EWST   4.3418
# ...            ...           ...      ...
# 1048568 2019-11-01            VT   2.5614
# 1048569 2019-12-01            VT   3.4494
# 1048572 2008-07-01           SZR   7.6445
# 1048573 2008-08-01           SZR  -4.0735
# 1048574 2008-09-01           SZR  -6.3134
#
# [1021412 rows x 3 columns]

# %%
df1 = df1[(df1['Date'] > '2014-12') & (df1['Date'] < '2020-01')]
df1.head(50)
# Out:
#           Date Ticker Symbol  Returns
# 96  2015-01-01          EGAS -11.5245
# 97  2015-02-01          EGAS   3.5897
# 98  2015-03-01          EGAS  -0.0495
# 99  2015-04-01          EGAS   1.1044
# 100 2015-05-01          EGAS  -0.6951
# 101 2015-06-01          EGAS        3
# 102 2015-07-01          EGAS  -1.3107
# 103 2015-08-01          EGAS -11.1665
# 104 2015-09-01          EGAS   0.3367
# 105 2015-10-01          EGAS   0.1678
# 106 2015-11-01          EGAS   -0.907
# 107 2015-12-01          EGAS -13.2151
# 108 2016-01-01          EGAS  11.6779
# 109 2016-02-01          EGAS  -5.5288
# 110 2016-03-01          EGAS  -0.6361
# 111 2016-04-01          EGAS  -5.5698
# 112 2016-05-01          EGAS  -2.1918
# 113 2016-06-01          EGAS  -2.1008
# 114 2016-07-01          EGAS   2.6466
# 115 2016-08-01          EGAS    3.662
# 116 2016-09-01          EGAS    4.212
# 117 2016-10-01          EGAS  61.9948
# 118 2016-11-01          EGAS   1.2146
# 119 2016-12-01          EGAS        1
# 120 2017-01-01          EGAS   0.7968
# 121 2017-02-01          EGAS        0
# 122 2017-03-01          EGAS   0.9881
# 123 2017-04-01          EGAS  -1.5748
# 124 2017-05-01          EGAS      1.6
# 125 2017-06-01          EGAS   2.3622
# 126 2017-07-01          EGAS   0.1934
# 298 2015-01-01          AEPI -13.8263
# 299 2015-02-01          AEPI   1.0976
# 300 2015-03-01          AEPI   8.6459
# 301 2015-04-01          AEPI  -8.9753
# 302 2015-05-01          AEPI  -0.1397
# 303 2015-06-01          AEPI  10.3338
# 304 2015-07-01          AEPI -12.4094
# 305 2015-08-01          AEPI  12.6163
# 306 2015-09-01          AEPI   5.2893
# 307 2015-10-01          AEPI   39.543
# 308 2015-11-01          AEPI   13.975
# 309 2015-12-01          AEPI -15.3871
# 310 2016-01-01          AEPI  10.0324
# 311 2016-02-01          AEPI  -7.0061
# 312 2016-03-01          AEPI -16.1479
# 313 2016-04-01          AEPI  -6.2424
# 314 2016-05-01          AEPI  -2.6286
# 315 2016-06-01          AEPI  34.0777
# 316 2016-07-01          AEPI   0.3107

# %%
df1 = df1.dropna(subset=['Ticker Symbol'])

# %%
fama = pd.read_excel('FF_Research_Data_Factors.xlsx')
fama = fama[['Date','Mkt-RF','RF']]
fama['Returns'] = fama['Mkt-RF']+fama['RF']
fama['Ticker Symbol']='SP500'
fama1 = fama[['Date','Ticker Symbol','Returns','RF']]
fama1['Date'] = fama1['Date'].apply(lambda x: pd.to_datetime(str(x), format='%Y%m'))
fama1
# Out:
#            Date Ticker Symbol  Returns    RF
# 0    1926-07-01         SP500     3.18  0.22
# 1    1926-08-01         SP500     2.89  0.25
# 2    1926-09-01         SP500     0.59  0.23
# 3    1926-10-01         SP500    -2.92  0.32
# 4    1926-11-01         SP500     2.84  0.31
# ...         ...           ...      ...   ...
# 1120 2019-11-01         SP500     3.99  0.12
# 1121 2019-12-01         SP500     2.91  0.14
# 1122 2020-01-01         SP500     0.02  0.13
# 1123 2020-02-01         SP500    -8.01  0.12
# 1124 2020-03-01         SP500   -13.27  0.12
#
# [1125 rows x 4 columns]

# %%
dfAll = pd.concat([df1,fama1])
dfAll = dfAll.reset_index()
dfAll = dfAll[(dfAll['Date'] > '2014-12-31') & (dfAll['Date'] < '2019-12-31')]
dfAll = dfAll[['Date','Ticker Symbol','Returns','RF']]
dfAll
# Out:
#              Date Ticker Symbol  Returns    RF
# 0      2015-01-01          EGAS -11.5245   NaN
# 1      2015-02-01          EGAS   3.5897   NaN
# 2      2015-03-01          EGAS  -0.0495   NaN
# 3      2015-04-01          EGAS   1.1044   NaN
# 4      2015-05-01          EGAS  -0.6951   NaN
# ...           ...           ...      ...   ...
# 413746 2019-08-01         SP500    -2.42  0.16
# 413747 2019-09-01         SP500     1.62  0.18
# 413748 2019-10-01         SP500     2.21  0.15
# 413749 2019-11-01         SP500     3.99  0.12
# 413750 2019-12-01         SP500     2.91  0.14
#
# [412689 rows x 4 columns]

# %%
stock_count = dfAll.groupby('Ticker Symbol')['Returns'].count()
stock_count = stock_count[stock_count == 60]
stocks = [*stock_count.keys()]
stocks
# Out:
# ['A',
#  'AADR',
#  'AAL',
#  'AAMC',
#  'AAME',
#  'AAN',
#  'AAOI',
#  'AAON',
#  'AAP',
#  'AAPL',
#  'AAT',
#  'AAU',
#  'AAWW',
#  'AB',
#  'ABB',
#  'ABBV',
#  'ABC',
#  'ABCB',
#  'ABDC',
#  'ABEV',
#  'ABG',
#  'ABIO',
#  'ABM',
#  'ABMD',
#  'ABR',
#  'ABT',
#  'ACAD',
#  'ACC',
#  'ACCO',
#  'ACGL',
#  'ACH',
#  'ACHC',
#  'ACHN',
#  'ACIW',
#  'ACLS',
#  'ACM',
#  'ACN',
#  'ACNB',
#  'ACOR',
#  'ACP',
#  'ACRE',
#  'ACRX',
#  'ACST',
#  'ACTG',
#  'ACU',
#  'ACWI',
#  'ACWV',
#  'ACWX',
#  'ACY',
#  'ADBE',
#  'ADC',
#  'ADI',
#  'ADM',
#  'ADMA',
#  'ADMP',
#  'ADMS',
#  'ADP',
#  'ADRA',
#  'ADRD',
#  'ADRE',
#  'ADRU',
#  'ADS',
#  'ADSK',
#  'ADTN',
#  'ADX',
#  'ADXS',
#  'AE',
#  'AEE',
#  'AEG',
#  'AEGN',
#  'AEHR',
#  'AEIS',
#  'AEL',
#  'AEM',
#  'AEO',
#  'AEP',
#  'AER',
#  'AERI',
#  'AES',
#  'AEY',
#  'AEZS',
#  'AFB',
#  'AFG',
#  'AFH',
#  'AFL',
#  'AFMD',
#  'AFT',
#  'AG',
#  'AGCO',
#  'AGD',
#  'AGEN',
#  'AGG',
#  'AGI',
#  'AGIO',
#  'AGNC',
#  'AGND',
#  'AGO',
#  'AGRO',
#  'AGRX',
#  'AGTC',
#  'AGX',
#  'AGYS',
#  'AGZD',
#  'AHC',
#  'AHH',
#  'AHPI',
#  'AHT',
#  'AI',
#  'AIA',
#  'AIF',
#  'AIG',
#  'AIMC',
#  'AIN',
#  'AINC',
#  'AINV',
#  'AIR',
#  'AIRI',
#  'AIRR',
#  'AIRT',
#  'AIT',
#  'AIV',
#  'AIZ',
#  'AJG',
#  'AKAM',
#  'AKBA',
#  'AKER',
#  'AKG',
#  'AKR',
#  'AKRX',
#  'AKS',
#  'AL',
#  'ALB',
#  'ALCO',
#  'ALDX',
#  'ALE',
#  'ALEX',
#  'ALFA',
#  'ALG',
#  'ALGN',
#  'ALGT',
#  'ALK',
#  'ALKS',
#  'ALL',
#  'ALLE',
#  'ALLT',
#  'ALLY',
#  'ALNY',
#  'ALOT',
#  'ALSK',
#  'ALSN',
#  'ALTS',
#  'ALV',
#  'ALX',
#  'ALXN',
#  'AM',
#  'AMAG',
#  'AMAT',
#  'AMBA',
#  'AMBC',
#  'AMC',
#  'AMCX',
#  'AMD',
#  'AME',
#  'AMED',
#  'AMG',
#  'AMGN',
#  'AMH',
#  'AMKR',
#  'AMLP',
#  'AMNB',
#  'AMOT',
#  'AMOV',
#  'AMP',
#  'AMPE',
#  'AMPH',
#  'AMRB',
#  'AMRC',
#  'AMRK',
#  'AMRN',
#  'AMRS',
#  'AMS',
#  'AMSC',
#  'AMSF',
#  'AMSWA',
#  'AMT',
#  'AMTD',
#  'AMTX',
#  'AMWD',
#  'AMX',
#  'AMZA',
#  'AMZN',
#  'AN',
#  'ANAT',
#  'ANDE',
#  'ANET',
#  'ANF',
#  'ANGL',
#  'ANGO',
#  'ANH',
#  'ANIK',
#  'ANIP',
#  'ANSS',
#  'ANTM',
#  'ANY',
#  'AOD',
#  'AON',
#  'AOS',
#  'AP',
#  'APA',
#  'APAM',
#  'APD',
#  'APDN',
#  'APEI',
#  'APH',
#  'APO',
#  'APOG',
#  'APPS',
#  'APT',
#  'APTO',
#  'APTS',
#  'APWC',
#  'AR',
#  'ARAY',
#  'ARC',
#  'ARCB',
#  'ARCC',
#  'ARCO',
#  'ARDC',
#  'ARDX',
#  'ARE',
#  'ARES',
#  'ARGT',
#  'ARKG',
#  'ARKK',
#  'ARKQ',
#  'ARKR',
#  'ARKW',
#  'ARL',
#  'ARLP',
#  'ARMK',
#  'ARNA',
#  'AROW',
#  'ARQL',
#  'ARR',
#  'ARTNA',
#  'ARTW',
#  'ARW',
#  'ARWR',
#  'ASA',
#  'ASB',
#  'ASC',
#  'ASEA',
#  'ASFI',
#  'ASG',
#  'ASGN',
#  'ASH',
#  'ASHR',
#  'ASHS',
#  'ASM',
#  'ASMB',
#  'ASML',
#  'ASNA',
#  'ASPN',
#  'ASR',
#  'ASTC',
#  'ASTE',
#  'ASUR',
#  'ASX',
#  'ASYS',
#  'AT',
#  'ATEC',
#  'ATEN',
#  'ATHM',
#  'ATHX',
#  'ATI',
#  'ATLC',
#  'ATLO',
#  'ATNI',
#  'ATNM',
#  'ATO',
#  'ATOS',
#  'ATR',
#  'ATRA',
#  'ATRC',
#  'ATRI',
#  'ATRO',
#  'ATRS',
#  'ATSG',
#  'ATTO',
#  'ATV',
#  'ATVI',
#  'AU',
#  'AUBN',
#  'AUDC',
#  'AUPH',
#  'AUY',
#  'AVA',
#  'AVAV',
#  'AVB',
#  'AVD',
#  'AVID',
#  'AVK',
#  'AVNW',
#  'AVP',
#  'AVT',
#  'AVX',
#  'AVY',
#  'AWF',
#  'AWI',
#  'AWK',
#  'AWP',
#  'AWR',
#  'AWRE',
#  'AWX',
#  'AXAS',
#  'AXDX',
#  'AXE',
#  'AXGN',
#  'AXJL',
#  'AXL',
#  'AXP',
#  'AXR',
#  'AXS',
#  'AXTA',
#  'AXTI',
#  'AXU',
#  'AYI',
#  'AYR',
#  'AZN',
#  'AZO',
#  'AZPN',
#  'AZZ',
#  'B',
#  'BA',
#  'BABA',
#  'BAC',
#  'BAF',
#  'BAH',
#  'BAM',
#  'BANC',
#  'BANF',
#  'BANR',
#  'BANX',
#  'BAP',
#  'BASI',
#  'BAX',
#  'BBBY',
#  'BBC',
#  'BBDO',
#  'BBF',
#  'BBGI',
#  'BBH',
#  'BBK',
#  'BBL',
#  'BBN',
#  'BBP',
#  'BBSI',
#  'BBVA',
#  'BBW',
#  'BBY',
#  'BC',
#  'BCBP',
#  'BCC',
#  'BCE',
#  'BCEI',
#  'BCH',
#  'BCLI',
#  'BCO',
#  'BCOM',
#  'BCOR',
#  'BCOV',
#  'BCPC',
#  'BCRH',
#  'BCRX',
#  'BCS',
#  'BCV',
#  'BCX',
#  'BDC',
#  'BDJ',
#  'BDL',
#  'BDN',
#  'BDR',
#  'BDSI',
#  'BDX',
#  'BEAT',
#  'BECN',
#  'BELFA',
#  'BELFB',
#  'BEN',
#  'BEP',
#  'BERY',
#  'BFAM',
#  'BFIN',
#  'BFK',
#  'BFO',
#  'BFOR',
#  'BFS',
#  'BFY',
#  'BFZ',
#  'BG',
#  'BGB',
#  'BGCP',
#  'BGFV',
#  'BGG',
#  'BGH',
#  'BGI',
#  'BGR',
#  'BGS',
#  'BGSF',
#  'BGT',
#  'BGX',
#  'BGY',
#  'BHB',
#  'BHE',
#  'BHK',
#  'BHLB',
#  'BHP',
#  'BHV',
#  'BIDU',
#  'BIF',
#  'BIG',
#  'BIIB',
#  'BIL',
#  'BIOC',
#  'BIOL',
#  'BIOS',
#  'BIP',
#  'BIT',
#  'BITA',
#  'BIV',
#  'BIZD',
#  'BJK',
#  'BJRI',
#  'BK',
#  'BKCC',
#  'BKD',
#  'BKE',
#  'BKEP',
#  'BKF',
#  'BKH',
#  'BKJ',
#  'BKK',
#  'BKLN',
#  'BKN',
#  'BKSC',
#  'BKT',
#  'BKU',
#  'BLCM',
#  'BLDP',
#  'BLDR',
#  'BLE',
#  'BLFS',
#  'BLIN',
#  'BLK',
#  'BLKB',
#  'BLL',
#  'BLMN',
#  'BLRX',
#  'BLUE',
#  'BLV',
#  'BLW',
#  'BLX',
#  'BMA',
#  'BME',
#  'BMI',
#  'BMO',
#  'BMRC',
#  'BMRN',
#  'BMTC',
#  'BMY',
#  'BND',
#  'BNDX',
#  'BNFT',
#  'BNS',
#  'BNSO',
#  'BNY',
#  'BOCH',
#  'BOE',
#  'BOH',
#  'BOIL',
#  'BOKF',
#  'BOND',
#  'BOOM',
#  'BOOT',
#  'BOSC',
#  'BOTJ',
#  'BP',
#  'BPFH',
#  'BPOP',
#  'BPT',
#  'BPTH',
#  'BPY',
#  'BQH',
#  'BR',
#  'BRC',
#  'BREW',
#  'BRFS',
#  'BRG',
#  'BRID',
#  'BRKL',
#  'BRKR',
#  'BRKS',
#  'BRN',
#  'BRO',
#  'BRT',
#  'BRX',
#  'BRZU',
#  'BSAC',
#  'BSD',
#  'BSE',
#  'BSET',
#  'BSMX',
#  'BSQR',
#  'BSRR',
#  'BST',
#  'BSTC',
#  'BSV',
#  'BSX',
#  'BTA',
#  'BTAL',
#  'BTE',
#  'BTG',
#  'BTI',
#  'BTN',
#  'BTO',
#  'BTT',
#  'BTZ',
#  'BUI',
#  'BURL',
#  'BUSE',
#  'BVN',
#  'BVSN',
#  'BWA',
#  'BWFG',
#  'BWG',
#  'BWL',
#  'BWX',
#  'BX',
#  'BXC',
#  'BXMT',
#  'BXMX',
#  'BXP',
#  'BXS',
#  'BYD',
#  'BYFC',
#  'BYLD',
#  'BYM',
#  'BZH',
#  'BZM',
#  'C',
#  'CAAS',
#  'CAC',
#  'CACC',
#  'CACI',
#  'CAE',
#  'CAF',
#  'CAG',
#  'CAH',
#  'CAJ',
#  'CAKE',
#  'CALA',
#  'CALM',
#  'CAMP',
#  'CAMT',
#  'CANE',
#  'CANF',
#  'CAPL',
#  'CAR',
#  'CARA',
#  'CARO',
#  'CART',
#  'CARV',
#  'CARZ',
#  'CASH',
#  'CASI',
#  'CASS',
#  'CASY',
#  'CAT',
#  'CATM',
#  'CATO',
#  'CATY',
#  'CB',
#  'CBAN',
#  'CBAY',
#  'CBB',
#  'CBFV',
#  'CBL',
#  'CBLI',
#  'CBMG',
#  'CBON',
#  'CBPX',
#  'CBRL',
#  'CBSH',
#  'CBT',
#  'CBU',
#  'CBZ',
#  'CCBG',
#  'CCCL',
#  'CCF',
#  'CCI',
#  'CCJ',
#  'CCK',
#  'CCL',
#  'CCLP',
#  'CCMP',
#  'CCNE',
#  'CCO',
#  'CCOI',
#  'CCRN',
#  'CCS',
#  'CCU',
#  'CCXI',
#  'CDC',
#  'CDE',
#  'CDK',
#  'CDNA',
#  'CDNS',
#  'CDR',
#  'CDW',
#  'CDZI',
#  'CE',
#  'CEA',
#  'CECE',
#  'CECO',
#  'CEE',
#  'CEL',
#  'CELP',
#  'CEMB',
#  'CEMI',
#  'CEN',
#  'CENT',
#  'CENTA',
#  'CENX',
#  'CEO',
#  'CEQP',
#  'CERN',
#  'CERS',
#  'CET',
#  'CETV',
#  'CEV',
#  'CEVA',
#  'CF',
#  'CFA',
#  'CFBK',
#  'CFFI',
#  'CFFN',
#  'CFG',
#  'CFO',
#  'CFR',
#  'CFRX',
#  'CFX',
#  'CG',
#  'CGEN',
#  'CGIX',
#  'CGNX',
#  'CGO',
#  'CHA',
#  'CHCI',
#  'CHCO',
#  'CHD',
#  'CHDN',
#  'CHE',
#  'CHEF',
#  'CHEP',
#  'CHGG',
#  'CHH',
#  'CHI',
#  'CHK',
#  'CHKP',
#  'CHKR',
#  'CHL',
#  'CHMG',
#  'CHMI',
#  'CHN',
#  'CHNR',
#  'CHRS',
#  'CHRW',
#  'CHS',
#  'CHT',
#  'CHTR',
#  'CHU',
#  'CHUY',
#  'CHW',
#  'CHY',
#  'CI',
#  'CIA',
#  'CIDM',
#  'CIEN',
#  'CIF',
#  'CIG',
#  'CII',
#  'CIK',
#  'CIM',
#  'CINF',
#  'CIO',
#  'CIR',
#  'CIX',
#  'CIZ',
#  'CIZN',
#  'CKH',
#  'CKX',
#  'CL',
#  'CLB',
#  'CLCT',
#  'CLDX',
#  'CLF',
#  'CLFD',
#  'CLGX',
#  'CLH',
#  'CLI',
#  'CLIR',
#  'CLM',
#  'CLMT',
#  'CLNE',
#  'CLR',
#  'CLRB',
#  'CLRO',
#  'CLS',
#  'CLSN',
#  'CLUB',
#  'CLVS',
#  'CLWT',
#  'CLX',
#  'CM',
#  'CMA',
#  'CMBS',
#  'CMC',
#  'CMCM',
#  'CMCO',
#  'CMCSA',
#  'CMCT',
#  'CME',
#  'CMF',
#  'CMG',
#  'CMI',
#  'CMO',
#  'CMP',
#  'CMPR',
#  'CMRE',
#  'CMRX',
#  'CMS',
#  'CMT',
#  'CMTL',
#  'CMU',
#  'CN',
#  'CNA',
#  'CNAT',
#  'CNBKA',
#  'CNC',
#  'CNCE',
#  'CNHI',
#  'CNI',
#  'CNK',
#  'CNMD',
#  'CNO',
#  'CNOB',
#  'CNP',
#  'CNQ',
#  'CNS',
#  'CNSL',
#  'CNTY',
#  'CNX',
#  'CNXT',
#  'CODI',
#  'COF',
#  'COG',
#  'COHR',
#  'COHU',
#  'COKE',
#  'COLB',
#  'COLM',
#  'COMM',
#  'COMT',
#  'CONE',
#  'CONN',
#  'COO',
#  'COP',
#  'COR',
#  'CORE',
#  'CORP',
#  'CORR',
#  'CORT',
#  'COST',
#  'COT',
#  'COTY',
#  'CP',
#  'CPA',
#  'CPAC',
#  'CPAH',
#  'CPB',
#  'CPE',
#  'CPER',
#  'CPF',
#  'CPG',
#  'CPHC',
#  'CPK',
#  'CPL',
#  'CPLP',
#  'CPRT',
#  'CPRX',
#  'CPS',
#  'CPSI',
#  'CPSS',
#  'CPST',
#  'CPT',
#  'CPTA',
#  'CQP',
#  'CR',
#  'CRAI',
#  'CRBN',
#  'CRC',
#  'CRCM',
#  'CREE',
#  'CRESY',
#  'CRF',
#  'CRH',
#  'CRI',
#  'CRIS',
#  'CRK',
#  'CRL',
#  'CRM',
#  'CRMT',
#  'CRNT',
#  'CROC',
#  'CROP',
#  'CROX',
#  'CRS',
#  'CRT',
#  'CRTO',
#  'CRUS',
#  'CRVL',
#  'CRWS',
#  'CRY',
#  'CS',
#  'CSCO',
#  'CSF',
#  'CSFL',
#  'CSGP',
#  'CSGS',
#  'CSII',
#  'CSIQ',
#  'CSL',
#  'CSLT',
#  'CSOD',
#  'CSPI',
#  'CSQ',
#  'CSS',
#  'CSTE',
#  'CSTM',
#  'CSU',
#  'CSV',
#  'CSWC',
#  'CSX',
#  'CTAS',
#  'CTB',
#  'CTBI',
#  'CTG',
#  'CTHR',
#  'CTIB',
#  'CTIC',
#  'CTL',
#  'CTLT',
#  'CTO',
#  'CTR',
#  'CTRE',
#  'CTRN',
#  'CTS',
#  'CTSH',
#  'CTSO',
#  'CTT',
#  'CTXS',
#  'CUB',
#  'CUBA',
#  'CUBE',
#  'CUBI',
#  'CUI',
#  'CUK',
#  'CUO',
#  'CURE',
#  'CUTR',
#  'CUZ',
#  'CVA',
#  'CVBF',
#  'CVCO',
#  'CVCY',
#  'CVEO',
#  'CVGI',
#  'CVGW',
#  'CVI',
#  'CVLT',
#  'CVLY',
#  'CVM',
#  'CVR',
#  'CVS',
#  'CVTI',
#  'CVU',
#  'CVV',
#  'CVX',
#  'CW',
#  'CWBC',
#  'CWCO',
#  'CWI',
#  'CWST',
#  'CWT',
#  'CX',
#  'CXE',
#  'CXH',
#  'CXO',
#  'CXP',
#  'CXW',
#  'CY',
#  'CYAN',
#  'CYB',
#  'CYBE',
#  'CYBR',
#  'CYCC',
#  'CYD',
#  'CYH',
#  'CYRN',
#  'CYTK',
#  'CZNC',
#  'CZR',
#  'CZWI',
#  'CZZ',
#  'D',
#  'DAC',
#  'DAIO',
#  'DAKT',
#  'DAL',
#  'DAN',
#  'DAR',
#  'DB',
#  'DBA',
#  'DBAW',
#  'DBB',
#  'DBC',
#  'DBD',
#  'DBE',
#  'DBEF',
#  'DBEM',
#  'DBEU',
#  'DBEZ',
#  'DBGR',
#  'DBJP',
#  'DBL',
#  'DBO',
#  'DBP',
#  'DBS',
#  'DBV',
#  'DBVT',
#  'DCI',
#  'DCIX',
#  'DCO',
#  'DCOM',
#  'DDD',
#  'DDF',
#  'DDG',
#  'DDM',
#  'DDS',
#  'DE',
#  'DECK',
#  'DEI',
#  'DEM',
#  'DENN',
#  'DEO',
#  'DERM',
#  'DES',
#  'DEW',
#  'DEX',
#  'DFE',
#  'DFJ',
#  'DFP',
#  'DFS',
#  'DGICA',
#  'DGICB',
#  'DGII',
#  'DGL',
#  'DGLY',
#  'DGRE',
#  'DGRO',
#  'DGRS',
#  'DGRW',
#  'DGS',
#  'DGT',
#  'DGX',
#  'DHF',
#  'DHI',
#  'DHIL',
#  'DHR',
#  'DHS',
#  'DHT',
#  'DHX',
#  'DHY',
#  'DIA',
#  'DIAX',
#  'DIG',
#  'DIM',
#  'DIN',
#  'DIOD',
#  'DIS',
#  ...]

# %%
dfAll1 = dfAll.loc[dfAll['Ticker Symbol'].isin(stocks)]
dfAll1.tail(60)
# Out:
#              Date Ticker Symbol Returns    RF
# 413691 2015-01-01         SP500   -3.11  0.00
# 413692 2015-02-01         SP500    6.13  0.00
# 413693 2015-03-01         SP500   -1.12  0.00
# 413694 2015-04-01         SP500    0.59  0.00
# 413695 2015-05-01         SP500    1.36  0.00
# 413696 2015-06-01         SP500   -1.53  0.00
df_row = df_row.reset_index()
df_row = df_row[(df_row['Date'] > '2014-12-31') & (df_row['Date'] < '2018-01-20')]
df_row = df_row.set_index('Date')
df_row['RiskFree']=fama1['RF'].iloc[-63:-27].values
df_row['ExcessReturn']=df_row['ROW']-df_row['RiskFree']
row = df_row['ExcessReturn'].values
row
# Out:
# array([ 0.7127538 ,  6.1599019 , -1.21833511,  3.86640908, -0.04837092,
#        -2.9107556 ,  1.46278837, -7.23340286, -4.08032533,  6.73400445,
#        -0.76236966, -2.14359917, -5.53833554, -3.10446529,  7.17096381,
#         2.30324499, -0.30965469, -2.07967061,  4.13721452,  0.38729469,
#         1.61785893, -2.42580591, -1.51638177,  2.41851907,  3.62722434,
#         1.01593714,  3.02843938,  2.16374528,  3.35050747,  0.57727504,
#         2.80993648, -0.06646896,  2.4243013 ,  1.68378009,  0.78011653,
#         1.56415031])

# %%
###Beta calculations###
###Want monthly return beta from 2015 to 2017###
dfAll1.reset_index()
dfBeta = dfAll1[(dfAll1['Date'] > '2014-12-31') & (dfAll1['Date'] < '2017-12-31')]
dfBeta = dfBeta.reset_index()
dfBeta = dfBeta[['Date','Ticker Symbol','Returns','RF']]
dfBeta
# Out:
#              Date Ticker Symbol Returns    RF
# 0      2015-01-01          JJSF -9.7913   NaN
# 1      2015-02-01          JJSF  3.1288   NaN
# 2      2015-03-01          JJSF   5.801   NaN
# 3      2015-04-01          JJSF -2.2212   NaN
# 4      2015-05-01          JJSF   3.326   NaN
# ...           ...           ...     ...   ...
# 159403 2017-08-01         SP500    0.25  0.09
# 159404 2017-09-01         SP500     2.6  0.09
# 159405 2017-10-01         SP500    2.34  0.09
# 159406 2017-11-01         SP500     3.2  0.08
# 159407 2017-12-01         SP500    1.15  0.09
#
# [159408 rows x 4 columns]

# %%
symbols = dfBeta.groupby('Ticker Symbol')
market_df = symbols.get_group('SP500')
market_df = market_df[['Date','Returns']].set_index('Date')
table = dfBeta.pivot(index='Date',columns='Ticker Symbol',values='Returns')  
table['RiskFree'] = fama1['RF'].iloc[-63:-27].values
table['ROW'] = row
table1 = table.reset_index()
table1
# Out:
# Ticker Symbol       Date        A     AADR      AAL     AAMC     AAME  \
# 0             2015-01-01  -7.4988  -2.5773  -8.4841 -48.4071  -0.9926
# 1             2015-02-01  11.7554   7.5791  -2.2005  10.6563   0.2506
# 2             2015-03-01  -1.3267  -1.2917  10.1879   4.5637     0.75
# 3             2015-04-01  -0.4332   4.0653   -8.327  20.9961  -1.2407
# 4             2015-05-01  -0.4351   0.0124 -12.2502  -23.933  -4.0404
# 5             2015-06-01  -6.0937  -3.6773   -5.747 -15.3178  -4.7368
# 6             2015-07-01   6.1431   3.6491   0.4132  -8.1225   2.7624
# 7             2015-08-01 -11.3309  -6.8414  -2.5436 -70.9663  -3.2258
# 8             2015-09-01  -5.1776  -4.1935  -0.3848  -37.776  12.2222
# 9             2015-10-01   9.9913   8.6139  19.0317    2.714   9.1584
# 13             -4.8913 -14.2276  -5.6075   0.929  -4.6225  14.0806     0.02
# 14              0.5714   8.0569  10.4668   5.472    7.964  -3.5818     0.02
# 15              0.5682    4.386  -1.2484  3.3528    6.305  -15.763     0.01
# 16            -10.7345   7.9832  -4.0194 -2.5163   0.8293  -11.323     0.01
# 17            -12.0253  -3.1128  -1.7225  2.3609   0.2847  -3.8306     0.02
# 18              1.4388   15.261  16.3215   4.256   6.3422  18.6583     0.02
# 19             -0.7092   -4.878  -9.7767  0.5873   1.2483   -1.649     0.02
# 20                   0   6.5934  -5.8528 -1.9209   1.7808   7.7844     0.02
# 21             -4.2857  -3.4364  -0.2131 -1.9684  -8.0946  23.6111     0.02
# 22             -1.4925   1.7794   2.2784 -2.7973   5.5962  11.4607     0.01
# 23              3.7879 -10.1399 -10.5117  8.0267   6.2525 -11.8952     0.03
# 24             -4.3796  -1.9455   12.641 -1.2209   2.8302   -8.238     0.04
# 25             -0.7634   5.1587  12.6727   3.484  -2.9669   1.7456     0.04
# 26             -7.6923   7.5472   1.9001  2.5346   0.1125 -10.2941     0.03
# 27              6.6667   1.4035  -1.6842  5.9881   5.3307  -1.9126     0.05
# 28              7.8125  21.7993  17.3142  2.4574  10.9963 -20.6128     0.06
# 29             148.551   3.4091   9.8601  1.7013   0.3292 -13.3333     0.06
# 30             16.9096  -0.8242  -7.8986  4.8574   0.2244    2.834     0.07
# 31            -16.7082   3.8781   1.2326  1.0899   0.2879  -1.9685     0.09
# 32              2.0958      0.8 -10.9585  1.2395   1.6906  45.3815     0.09
# 33            -24.6334   3.1746   7.5938  1.9167   0.0941  -2.4862     0.09
# 34            -21.0117   5.1282  21.6063  0.7721  13.4362  23.5127     0.08
# 35              6.4039   -2.439  15.2324  1.3728  -0.3458  -4.4725     0.09
#
# Ticker Symbol       ROW
# 0              0.712754
# 1              6.159902
# 2             -1.218335
# 3              3.866409
# 4             -0.048371
# 5             -2.910756
# 6              1.462788
# 7             -7.233403
# 8             -4.080325
# 9              6.734004
# 10            -0.762370
# 11            -2.143599
# 12            -5.538336
# 13            -3.104465
# 14             7.170964
# 15             2.303245
# 16            -0.309655
# 17            -2.079671
# 18             4.137215
# 19             0.387295
# 20             1.617859
# 21            -2.425806
# 22            -1.516382
# 23             2.418519
# 24             3.627224
# 25             1.015937
# 26             3.028439
# 27             2.163745
# 28             3.350507
# 29             0.577275
# 30             2.809936
# 31            -0.066469
# 32             2.424301
# 33             1.683780
# 34             0.780117
# 35             1.564150
#
# [36 rows x 4431 columns]

# %%
beta_df = []
for stock in stocks:
    table1[stock] = table1[stock]-table1['RiskFree']
    beta_df.append({'Date':table1['Date'], 'Ticker':stock, 'ExcessReturn': table1[stock]})
beta_df = pd.DataFrame(beta_df)
beta_df1 = beta_df.set_index(['Ticker']).apply(pd.Series.explode).reset_index()

# %%
beta_df2 = beta_df1.pivot(index='Date',columns='Ticker',values='ExcessReturn')
beta_df2
# Out:
# 2016-12-01   3.4587   3.7579 -10.1699 -10.5417  7.9967   6.2225 -11.9252
# 2017-01-01   4.1995  -4.4196  -1.9855   12.601 -1.2609   2.7902   -8.278
# 2017-02-01  -1.4132  -0.8034   5.1187  12.6327   3.444  -3.0069   1.7056
# 2017-03-01  -1.1635  -7.7223   7.5172   1.8701  2.5046   0.0825 -10.3241
# 2017-04-01  -2.1267   6.6167   1.3535  -1.7342  5.9381   5.2807  -1.9626
# 2017-05-01  -5.0029   7.7525  21.7393  17.2542  2.3974  10.9363 -20.6728
# 2017-06-01   0.1631  148.491   3.3491   9.8001  1.6413   0.2692 -13.3933
# 2017-07-01   2.9674  16.8396  -0.8942  -7.9686  4.7874   0.1544    2.764
# 2017-08-01  -5.1864 -16.7982   3.7881   1.1426  0.9999   0.1979  -2.0585
# 2017-09-01   1.3974   2.0058     0.71 -11.0485  1.1495   1.6006  45.2915
# 2017-10-01  -3.0147 -24.7234   3.0846   7.5038  1.8267   0.0041  -2.5762
# 2017-11-01  -2.0968 -21.0917   5.0482  21.5263  0.6921  13.3562  23.4327
# 2017-12-01   3.8048   6.3139   -2.529  15.1424  1.2828  -0.4358  -4.5625
#
# [36 rows x 4429 columns]

# %%
y = beta_df2[['A']].values
x = beta_df2[['SP500', 'ROW']] 
regr = linear_model.LinearRegression()
regr.fit(x, y)
model = sm.OLS(y.astype(float), x.astype(float)).fit()
beta = model.params
beta
# Out:
# SP500    1.119877
# ROW      0.489889
# dtype: float64

# %%
equities = beta_df2.columns
main_df = []
for equity in equities:
    y = beta_df2[[equity]].values
    x = beta_df2[['SP500', 'ROW']] 
    regr = linear_model.LinearRegression()
    regr.fit(x, y)
    model = sm.OLS(y.astype(float), x.astype(float)).fit()
    predictions = model.predict(x) 
    beta = regr.coef_
    main_df.append({'Ticker':equity, 'Beta': beta})
main_df = pd.DataFrame(main_df)
main_df
# Out:
#      Ticker                                         Beta
# 0         A   [[1.0889451765621174, 0.4969234397292245]]
# 1      AADR  [[0.15184913069105604, 0.8765460670815707]]
# 2       AAL  [[1.9518373503314175, -0.9137785933137746]]
# 3      AAMC  [[-1.6299872789330803, 3.8696182892071396]]
# 4      AAME  [[0.7371771864114728, -0.4374979928596947]]
# ...     ...                                          ...
# 4424   ZNGA  [[0.4468068496401524, 0.08569497293798059]]
# 4425    ZNH  [[-0.2126681821446833, 1.7233289198315018]]
# 4426    ZTR  [[0.21889372375032334, 0.5668600560331408]]
# 4427    ZTS  [[0.9264466268685723, 0.34339524020662293]]
# 4428   ZUMZ  [[2.6757816065783158, -1.9049492804555255]]
#
# [4429 rows x 2 columns]

# %%
equities = beta_df2.columns
main_df = []
for equity in equities:    
    y = beta_df2[[equity]].values
    x = beta_df2[['SP500', 'ROW']] 
    regr = linear_model.LinearRegression()
    regr.fit(x, y)
    model = sm.OLS(y.astype(float), x.astype(float)).fit()
    beta = model.params 
    main_df.append({'Ticker':equity, 'Beta': beta[0], 'Gamma': beta[1]})
main_df = pd.DataFrame(main_df)
main_df
# Out:
#      Ticker      Beta     Gamma
# 0         A  1.119877  0.489889
# 1      AADR  0.226513  0.859566
# 2       AAL  1.854276 -0.891591
# 3      AAMC -1.650759  3.874342
# 4      AAME  0.673115 -0.422929
# ...     ...       ...       ...
# 4424   ZNGA  0.574119  0.056742
# 4425    ZNH  0.077873  1.657254
# 4426    ZTR  0.246025  0.560690
# 4427    ZTS  0.989983  0.328946
# 4428   ZUMZ  2.454939 -1.854725
#
# [4429 rows x 3 columns]

# %%
main_df1 = main_df.set_index('Ticker')
#main_df1.to_excel('beta_regression.xlsx')

# %%
x = main_df1.index
drop = x[3433]
x = x.drop(drop)

# %%
df_stock_returns = dfAll1[(dfAll1['Date'] > '2017-12-20') & (dfAll1['Date'] < '2019-12-31')]
stock_annual_returns = df_stock_returns.loc[df_stock_returns['Ticker Symbol'].isin(stocks)]
stock_returns = stock_annual_returns.pivot(index='Date',columns='Ticker Symbol',values='Returns')
stock_returns['Risk Free Rate'] = fama1['RF'].iloc[-27:-3].values
stock_returns = stock_returns.reset_index()
stock_returns_previous = []
for equity in x:
    excess_returns = stock_returns[equity]-stock_returns['Risk Free Rate']
    stock_returns_previous.append({'Ticker':equity, 'Excess Return': stock_returns[equity].sum()})
stock_returns_previous = pd.DataFrame(stock_returns_previous)
stock_returns_previous
# Out:
#      Ticker  Excess Return
# 0         A        32.0401
# 1      AADR        -3.9323
# 2       AAL       -42.2322
# 3      AAMC      -138.4771
# 4      AAME       -42.4079
# ...     ...            ...
# 4423   ZNGA        52.4130
# 4424    ZNH       -18.9222
# 4425    ZTR        12.9024
# 4426    ZTS        65.6205
# 4427   ZUMZ        79.2374
#
# [4428 rows x 2 columns]

# %%
stock_returns_previous['Annual Excess Return'] = stock_returns_previous['Excess Return']/2
excess_return_df = stock_returns_previous[['Ticker', 'Annual Excess Return']].set_index('Ticker')
#excess_return_df.to_excel('ExcessReturnRegression.xlsx')

# %%
main = pd.read_excel('beta_regression_gammasorted.xlsx')

# %%
x = main.columns[2]
type(x)
# Out:
# str

# %%
###gamma of each portfolio sorted from highest to lowest beta
group_size = 442
portfolios = [main.iloc[i:i+group_size] for i in range(0,len(main)-group_size+1,group_size)]   
for portfolio in portfolios:
    print(portfolio['Gamma'].mean())
# Out:
# 2.092397550756023
# 1.0280464625114907
# 0.6514328866163673
# 0.4018926848632953
# 0.19746906353652138
# -0.011846939603507058
# -0.24639305217124755
# -0.5526691196876258
# -0.9577756048578648
# -1.8306288101295298

# %%
###annual returns of each portfolio sorted from highest to lowest gamma
group_size = 442
portfolios = [main.iloc[i:i+group_size] for i in range(0,len(main)-group_size+1,group_size)]   
for portfolio in portfolios:
    print(portfolio['Annual Excess Return'].mean())
# Out:
# 3.597827375565609
# 3.5068822398190056
# 7.3935423076923055
# 6.898510180995477
# 7.701186312217194
# 7.674458710407236
# 6.652574886877828
# 4.561608936651586
# 7.23288190045249
# 4.731469004524883
